# %% [markdown]
# # 1 - Data Extraction
#
# Here we will download all the data we need.
#
# Because it is too large (about 150 GB), we'll also apply some pre-processing on the data.

# %%
# imports
import os
import json
import requests
import pandas as pd
from tqdm import tqdm

# %%
# dotenv incantations
from dotenv import load_dotenv, find_dotenv

# find .env automagically by walking up directories until it's found
dotenv_path = find_dotenv()

# load up the entries as environment variables
load_dotenv(dotenv_path)
# Out:
# True

# %% [markdown]
# ## 1.1. OpenDataSUS - Jab data
#
# First, let's extract the jabs data. This is a dataset of each and every COVID jab applied in Brazil.

# %%
# get API connection info via .env file
COVIDJAB_API_URL = os.environ.get("COVIDJAB_API_URL")
COVIDJAB_API_URL_FIRST = os.environ.get("COVIDJAB_API_URL_FIRST")
COVIDJAB_API_USER = os.environ.get("COVIDJAB_API_USER")
COVIDJAB_API_PASSWD = os.environ.get("COVIDJAB_API_PASSWD")

api_auth = requests.auth.HTTPBasicAuth(
    COVIDJAB_API_USER,
    COVIDJAB_API_PASSWD
)

print(f'API URL: "{COVIDJAB_API_URL}"')
print(f'API URL (first page): "{COVIDJAB_API_URL_FIRST}"')
print(f'API username: "{COVIDJAB_API_USER}"')
print(f'API password: "{COVIDJAB_API_PASSWD}"')
# Out:
# API URL: "https://imunizacao-es.saude.gov.br/_search/scroll"
# API URL (first page): "https://imunizacao-es.saude.gov.br/_search?scroll=1m"
# API username: "imunizacao_public"
# API password: "qlto5t&7r_@+#Tlstigi"

# %%
# establish request params
payload = {
    'size': 5,
}

# %%
# extract via requests
html = requests.post(COVIDJAB_API_URL_FIRST, 
    auth = api_auth,
    json = payload,
)
json_data = html.json()
print(json.dumps(json_data, indent = 3))
# Out:
# {
#    "_scroll_id": "...-JIWU21WOEFHMWRTalNsWmRHSW51bjJEURZLZUlSV29fQlRwT0tTSW5RZ1ctOHRBAAAAAITzV94WSV80VGNNRVRUU0NUU0RBYzFoTlNkURZXUVF0NFRwM1F2R3FhN0V1ak1jWEhBAAAAAFSc-JQWU21WOEFHMWRTalNsWmRHSW51bjJEURZXUVF0NFRwM1F2R3FhN0V1ak1jWEhBAAAAAFSc-JMWU21WOEFHMWRTalNsWmRHSW51bjJEURZxU1MyTmZYclFSS3J1Z3FYbUd0TGtnAAAAAABEUpgWWVFUMmExdmNTVFdQTURWVmxtQl9zZxZxU1MyTmZYclFSS3J1Z3FYbUd0TGtnAAAAAABEUpoWWVFUMmExdmNTVFdQTURWVmxtQl9zZxZXUVF0NFRwM1F2R3FhN0V1ak1jWEhBAAAAAFSc-JUWU21WOEFHMWRTalNsWmRHSW51bjJEURZxU1MyTmZYclFSS3J1Z3FYbUd0TGtnAAAAAABEUpkWWVFUMmExdmNTVFdQTURWVmxtQl9zZw==",
#    "took": 8,
#    "timed_out": false,
#    "_shards": {
#       "total": 30,
#       "successful": 30,
#       "skipped": 0,
#       "failed": 0
#    },
#    "hits": {
#       "total": {
#          "value": 539500133,
#          "relation": "eq"
#       },
#       "max_score": 1.0,
#       "hits": [
#          {
#             "_index": "desc-imunizacao-v5",
#             "_type": "_doc",
#             "_id": "49801a07-d2b7-4f8a-8f4d-82c02b51ef1a-i0b0",
#             "_score": 1.0,
#             "_source": {
#                "estalecimento_noFantasia": "SAE DST AIDS CIDADE DUTRA",
#                "vacina_lote": "221VCD031W",
#                "estabelecimento_municipio_codigo": "355030",
#                "estabelecimento_valor": "4049802",
#                "vacina_nome": "COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD",
#                "ds_condicao_maternal": null,
#                "paciente_endereco_coPais": "10",
#                "@version": "1",
#                "document_id": "49801a07-d2b7-4f8a-8f4d-82c02b51ef1a-i0b0",
#                "paciente_nacionalidade_enumNacionalidade": "B",
#                "vacina_categoria_codigo": "1",
#                "vacina_fabricante_referencia": null,
#                "paciente_id": "4978607ded901352f7febd9ca9c6c3fd69b2f2a945e24bc378cea1653c04de4e",
#                "paciente_idade": 46,
#                "vacina_descricao_dose": "2\u00ba Refor\u00e7o",
#                "paciente_endereco_coIbgeMunicipio": "355030",
#                "vacina_grupoAtendimento_codigo": "000111",
#                "data_importacao_datalake": "2023-02-01T07:14:44.000Z",
#                "paciente_racaCor_codigo": "99",
#                "estabelecimento_uf": "SP",
#                "estabelecimento_razaoSocial": "PREFEITURA DO MUNICIPIO DE SAO PAULO",
#                "vacina_numDose": "7",
#                "@timestamp": "2023-02-01T09:17:24.173Z",
#                "sistema_origem": "VACIVIDA",
#                "paciente_dataNascimento": "1976-07-29",
#                "paciente_endereco_uf": "SP",
#                "vacina_fabricante_nome": "ASTRAZENECA/FIOCRUZ",
#                "paciente_endereco_cep": "None",
#                "id_sistema_origem": "18262",
#                "status": "entered-in-error",
#                "paciente_endereco_nmPais": "BRASIL",
#                "vacina_categoria_nome": "Comorbidades",
#                "paciente_endereco_nmMunicipio": "SAO PAULO",
#                "estabelecimento_municipio_nome": "SAO PAULO",
#                "vacina_codigo": "85",
#                "paciente_enumSexoBiologico": "M",
#                "dt_deleted": "2023-02-01T00:00:00.000Z",
#                "co_condicao_maternal": null,
#                "vacina_grupoAtendimento_nome": "Outros Imunocomprometidos",
#                "paciente_racaCor_valor": "SEM INFORMACAO",
#                "vacina_dataAplicacao": "2022-10-18T00:00:00.000Z",
#                "data_importacao_rnds": "2022-10-18T10:56:11.000Z"
#             }
#          },
#          {
#             "_index": "desc-imunizacao-v5",
#             "_type": "_doc",
#             "_id": "72c090ff-76f7-4812-87bc-3aaaa20bf040-i0b0",
#             "_score": 1.0,
#             "_source": {
#                "estalecimento_noFantasia": "UBS PARQUE SANTO ANTONIO",
#                "vacina_lote": "221VCD042Z",
#                "estabelecimento_municipio_codigo": "352440",
#                "estabelecimento_valor": "2086522",
#                "vacina_nome": "COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD",
#                "ds_condicao_maternal": null,
#                "paciente_endereco_coPais": "10",
#                "@version": "1",
#                "document_id": "72c090ff-76f7-4812-87bc-3aaaa20bf040-i0b0",
#                "paciente_nacionalidade_enumNacionalidade": "B",
#                "vacina_categoria_codigo": "1",
#                "vacina_fabricante_referencia": null,
#                "paciente_id": "b3c43a541aabdaee625aa5fcd46a13441b82d6cf764fa80ff6bc8e5e4831fa15",
#                "paciente_idade": 55,
#                "vacina_descricao_dose": "2\u00ba Refor\u00e7o",
#                "paciente_endereco_coIbgeMunicipio": "352440",
#                "vacina_grupoAtendimento_codigo": "000103",
#                "data_importacao_datalake": "2023-02-01T07:14:44.000Z",
#                "paciente_racaCor_codigo": "99",
#                "estabelecimento_uf": "SP",
#                "estabelecimento_razaoSocial": "PREFEITURA MUNICIPAL DE JACAREI",
#                "vacina_numDose": "7",
#                "@timestamp": "2023-02-01T09:17:24.176Z",
#                "sistema_origem": "VACIVIDA",
#                "paciente_dataNascimento": "1967-08-01",
#                "paciente_endereco_uf": "SP",
#                "vacina_fabricante_nome": "ASTRAZENECA/FIOCRUZ",
#                "paciente_endereco_cep": "12308",
#                "id_sistema_origem": "18262",
#                "status": "entered-in-error",
#                "paciente_endereco_nmPais": "BRASIL",
#                "vacina_categoria_nome": "Comorbidades",
#                "paciente_endereco_nmMunicipio": "JACAREI",
#                "estabelecimento_municipio_nome": "JACAREI",
#                "vacina_codigo": "85",
#                "paciente_enumSexoBiologico": "M",
#                "dt_deleted": "2023-02-01T00:00:00.000Z",
#                "co_condicao_maternal": null,
#                "vacina_grupoAtendimento_nome": "Diabetes Mellitus",
#                "paciente_racaCor_valor": "SEM INFORMACAO",
#                "vacina_dataAplicacao": "2022-10-03T00:00:00.000Z",
#                "data_importacao_rnds": "2022-10-03T14:47:47.000Z"
#             }
#          },
#          {
#             "_index": "desc-imunizacao-v5",
#             "_type": "_doc",
#             "_id": "35060758-62ec-472b-a6cd-72100e36954b-i0b0",
#             "_score": 1.0,
#             "_source": {
#                "estalecimento_noFantasia": "UBS 3 DR PEDRO SILVEIRA MARTINS XII DE SETEMBRO",
#                "vacina_lote": "FT5177",
#                "estabelecimento_municipio_codigo": "352470",
#                "estabelecimento_valor": "2023482",
#                "vacina_nome": "COVID-19 PFIZER - COMIRNATY",
#                "ds_condicao_maternal": null,
#                "paciente_endereco_coPais": "10",
#                "@version": "1",
#                "document_id": "35060758-62ec-472b-a6cd-72100e36954b-i0b0",
#                "paciente_nacionalidade_enumNacionalidade": "B",
#                "vacina_categoria_codigo": "2",
#                "vacina_fabricante_referencia": null,
#                "paciente_id": "c7f99d45401c30550a8a6a12b4266bd35261e433ddd5b1b0d87b3fc047b2e13f",
#                "paciente_idade": 37,
#                "vacina_descricao_dose": "2\u00ba Refor\u00e7o",
#                "paciente_endereco_coIbgeMunicipio": "352470",
#                "vacina_grupoAtendimento_codigo": "000201",
#                "data_importacao_datalake": "2023-02-01T07:14:44.000Z",
#                "paciente_racaCor_codigo": "01",
#                "estabelecimento_uf": "SP",
#                "estabelecimento_razaoSocial": "PREFEITURA MUNICIPAL DE JAGUARIUNA",
#                "vacina_numDose": "7",
#                "@timestamp": "2023-02-01T09:17:24.177Z",
#                "sistema_origem": "VACIVIDA",
#                "paciente_dataNascimento": "1985-06-19",
#                "paciente_endereco_uf": "SP",
#                "vacina_fabricante_nome": "PFIZER",
#                "paciente_endereco_cep": "13820",
#                "id_sistema_origem": "18262",
#                "status": "entered-in-error",
#                "paciente_endereco_nmPais": "BRASIL",
#                "vacina_categoria_nome": "Faixa Et\u00e1ria",
#                "paciente_endereco_nmMunicipio": "JAGUARIUNA",
#                "estabelecimento_municipio_nome": "JAGUARIUNA",
#                "vacina_codigo": "87",
#                "paciente_enumSexoBiologico": "M",
#                "dt_deleted": "2023-02-01T00:00:00.000Z",
#                "co_condicao_maternal": null,
#                "vacina_grupoAtendimento_nome": "Pessoas de 18 a 64 anos",
#                "paciente_racaCor_valor": "BRANCA",
#                "vacina_dataAplicacao": "2022-11-07T00:00:00.000Z",
#                "data_importacao_rnds": "2022-11-07T16:46:53.000Z"
#             }
#          },
#          {
#             "_index": "desc-imunizacao-v5",
#             "_type": "_doc",
#             "_id": "a8438d39-7022-4439-a362-137f9e80108a-i0b0",
#             "_score": 1.0,
#             "_source": {
#                "estalecimento_noFantasia": "UBS PAULO FELDMAN NITRO OPERARIA",
#                "vacina_lote": "211J21A",
#                "estabelecimento_municipio_codigo": "355030",
#                "estabelecimento_valor": "2788209",
#                "vacina_nome": "COVID-19 JANSSEN - Ad26.COV2.S",
#                "ds_condicao_maternal": null,
#                "paciente_endereco_coPais": "10",
#                "@version": "1",
#                "document_id": "a8438d39-7022-4439-a362-137f9e80108a-i0b0",
#                "paciente_nacionalidade_enumNacionalidade": "B",
#                "vacina_categoria_codigo": "2",
#                "vacina_fabricante_referencia": null,
#                "paciente_id": "5661a6726bd31340cc35b263fa56cf0cadd0a069423fee0485e08fe042f48986",
#                "paciente_idade": 58,
#                "vacina_descricao_dose": "2\u00ba Refor\u00e7o",
#                "paciente_endereco_coIbgeMunicipio": "355030",
#                "vacina_grupoAtendimento_codigo": "000201",
#                "data_importacao_datalake": "2023-02-01T07:14:44.000Z",
#                "paciente_racaCor_codigo": "99",
#                "estabelecimento_uf": "SP",
#                "estabelecimento_razaoSocial": "PREFEITURA DO MUNICIPIO DE SAO PAULO",
#                "vacina_numDose": "7",
#                "@timestamp": "2023-02-01T09:17:24.178Z",
#                "sistema_origem": "VACIVIDA",
#                "paciente_dataNascimento": "1964-09-20",
#                "paciente_endereco_uf": "SP",
#                "vacina_fabricante_nome": "JANSSEN",
#                "paciente_endereco_cep": "None",
#                "id_sistema_origem": "18262",
#                "status": "entered-in-error",
#                "paciente_endereco_nmPais": "BRASIL",
#                "vacina_categoria_nome": "Faixa Et\u00e1ria",
#                "paciente_endereco_nmMunicipio": "SAO PAULO",
#                "estabelecimento_municipio_nome": "SAO PAULO",
#                "vacina_codigo": "88",
#                "paciente_enumSexoBiologico": "F",
#                "dt_deleted": "2023-02-01T00:00:00.000Z",
#                "co_condicao_maternal": null,
#                "vacina_grupoAtendimento_nome": "Pessoas de 18 a 64 anos",
#                "paciente_racaCor_valor": "SEM INFORMACAO",
#                "vacina_dataAplicacao": "2022-11-09T00:00:00.000Z",
#                "data_importacao_rnds": "2022-11-09T10:25:50.000Z"
#             }
#          },
#          {
#             "_index": "desc-imunizacao-v5",
#             "_type": "_doc",
#             "_id": "ca46a2a8-d18e-463b-9b99-867112995c69-i0b0",
#             "_score": 1.0,
#             "_source": {
#                "estalecimento_noFantasia": "UBS ARARA DOS MORI",
#                "vacina_lote": "220255",
#                "estabelecimento_municipio_codigo": "350760",
#                "estabelecimento_valor": "2688352",
#                "vacina_nome": "COVID-19 SINOVAC/BUTANTAN - CORONAVAC",
#                "ds_condicao_maternal": null,
#                "paciente_endereco_coPais": "10",
#                "@version": "1",
#                "document_id": "ca46a2a8-d18e-463b-9b99-867112995c69-i0b0",
#                "paciente_nacionalidade_enumNacionalidade": "B",
#                "vacina_categoria_codigo": "2",
#                "vacina_fabricante_referencia": null,
#                "paciente_id": "51ea1decef5c165c9405f8e9a74c9499f85d2d0a27297d3383fb6f2ec2d4ddb6",
#                "paciente_idade": 52,
#                "vacina_descricao_dose": "2\u00ba Refor\u00e7o",
#                "paciente_endereco_coIbgeMunicipio": "350760",
#                "vacina_grupoAtendimento_codigo": "000201",
#                "data_importacao_datalake": "2023-02-01T07:14:44.000Z",
#                "paciente_racaCor_codigo": "01",
#                "estabelecimento_uf": "SP",
#                "estabelecimento_razaoSocial": "PREFEITURA MUNIC BRAGANCA PAULISTA",
#                "vacina_numDose": "7",
#                "@timestamp": "2023-02-01T09:17:24.178Z",
#                "sistema_origem": "VACIVIDA",
#                "paciente_dataNascimento": "1970-06-04",
#                "paciente_endereco_uf": "SP",
#                "vacina_fabricante_nome": "SINOVAC/BUTANTAN",
#                "paciente_endereco_cep": "12903",
#                "id_sistema_origem": "18262",
#                "status": "entered-in-error",
#                "paciente_endereco_nmPais": "BRASIL",
#                "vacina_categoria_nome": "Faixa Et\u00e1ria",
#                "paciente_endereco_nmMunicipio": "BRAGANCA PAULISTA",
#                "estabelecimento_municipio_nome": "BRAGANCA PAULISTA",
#                "vacina_codigo": "86",
#                "paciente_enumSexoBiologico": "M",
#                "dt_deleted": "2023-02-01T00:00:00.000Z",
#                "co_condicao_maternal": null,
#                "vacina_grupoAtendimento_nome": "Pessoas de 18 a 64 anos",
#                "paciente_racaCor_valor": "BRANCA",
#                "vacina_dataAplicacao": "2022-11-10T00:00:00.000Z",
#                "data_importacao_rnds": "2022-11-10T13:50:38.000Z"
#             }
#          }
#       ]
#    }
# }

# %%
# extract 2nd page

payload = {
    'scroll_id': json_data['_scroll_id'],
    'scroll': '1m'
}

html = requests.post(COVIDJAB_API_URL, 
    auth = api_auth,
    json = payload,
)
json_data = html.json()
print(json.dumps(json_data, indent=3))
# Out:
# {
#    "_scroll_id": "...-JIWU21WOEFHMWRTalNsWmRHSW51bjJEURZLZUlSV29fQlRwT0tTSW5RZ1ctOHRBAAAAAITzV94WSV80VGNNRVRUU0NUU0RBYzFoTlNkURZXUVF0NFRwM1F2R3FhN0V1ak1jWEhBAAAAAFSc-JQWU21WOEFHMWRTalNsWmRHSW51bjJEURZXUVF0NFRwM1F2R3FhN0V1ak1jWEhBAAAAAFSc-JMWU21WOEFHMWRTalNsWmRHSW51bjJEURZxU1MyTmZYclFSS3J1Z3FYbUd0TGtnAAAAAABEUpgWWVFUMmExdmNTVFdQTURWVmxtQl9zZxZxU1MyTmZYclFSS3J1Z3FYbUd0TGtnAAAAAABEUpoWWVFUMmExdmNTVFdQTURWVmxtQl9zZxZXUVF0NFRwM1F2R3FhN0V1ak1jWEhBAAAAAFSc-JUWU21WOEFHMWRTalNsWmRHSW51bjJEURZxU1MyTmZYclFSS3J1Z3FYbUd0TGtnAAAAAABEUpkWWVFUMmExdmNTVFdQTURWVmxtQl9zZw==",
#    "took": 5,
#    "timed_out": false,
#    "terminated_early": true,
#    "_shards": {
#       "total": 30,
#       "successful": 30,
#       "skipped": 0,
#       "failed": 0
#    },
#    "hits": {
#       "total": {
#          "value": 539500133,
#          "relation": "eq"
#       },
#       "max_score": 1.0,
#       "hits": [
#          {
#             "_index": "desc-imunizacao-v5",
#             "_type": "_doc",
#             "_id": "171a0693-332e-4690-8a51-ae7f0427ddd4-i0b0",
#             "_score": 1.0,
#             "_source": {
#                "estalecimento_noFantasia": "UBS EURIPES DE FATIMA GALDINO PELE",
#                "vacina_lote": "210556A",
#                "estabelecimento_municipio_codigo": "352310",
#                "estabelecimento_valor": "2773236",
#                "vacina_nome": "COVID-19 SINOVAC/BUTANTAN - CORONAVAC",
#                "ds_condicao_maternal": null,
#                "paciente_endereco_coPais": "10",
#                "@version": "1",
#                "document_id": "171a0693-332e-4690-8a51-ae7f0427ddd4-i0b0",
#                "paciente_nacionalidade_enumNacionalidade": "B",
#                "vacina_categoria_codigo": "2",
#                "vacina_fabricante_referencia": null,
#                "paciente_id": "39a1995fd4e6f8650064f4a6a393ec3fb0a77bf5943854831df7b37c80129fd8",
#                "paciente_idade": 18,
#                "vacina_descricao_dose": "Refor\u00e7o",
#                "paciente_endereco_coIbgeMunicipio": "351880",
#                "vacina_grupoAtendimento_codigo": "000201",
#                "data_importacao_datalake": "2023-02-01T07:14:44.000Z",
#                "paciente_racaCor_codigo": "04",
#                "estabelecimento_uf": "SP",
#                "estabelecimento_razaoSocial": "MUNICIPIO DE ITAQUAQUECETUBA",
#                "vacina_numDose": "38",
#                "@timestamp": "2023-02-01T09:17:24.206Z",
#                "sistema_origem": "VACIVIDA",
#                "paciente_dataNascimento": "2003-11-29",
#                "paciente_endereco_uf": "SP",
#                "vacina_fabricante_nome": "SINOVAC/BUTANTAN",
#                "paciente_endereco_cep": "07152",
#                "id_sistema_origem": "18262",
#                "status": "entered-in-error",
#                "paciente_endereco_nmPais": "BRASIL",
#                "vacina_categoria_nome": "Faixa Et\u00e1ria",
#                "paciente_endereco_nmMunicipio": "GUARULHOS",
#                "estabelecimento_municipio_nome": "ITAQUAQUECETUBA",
#                "vacina_codigo": "86",
#                "paciente_enumSexoBiologico": "F",
#                "dt_deleted": "2023-02-01T00:00:00.000Z",
#                "co_condicao_maternal": null,
#                "vacina_grupoAtendimento_nome": "Pessoas de 18 a 64 anos",
#                "paciente_racaCor_valor": "AMARELA",
#                "vacina_dataAplicacao": "2022-10-03T00:00:00.000Z",
#                "data_importacao_rnds": "2022-10-03T19:06:24.000Z"
#             }
#          },
#          {
#             "_index": "desc-imunizacao-v5",
#             "_type": "_doc",
#             "_id": "d784dd2d-87e3-4e45-be44-48a6590d9b0f-i0b0",
#             "_score": 1.0,
#             "_source": {
#                "estalecimento_noFantasia": "AMA UBS INTEGRADA JD BRASILIA",
#                "vacina_lote": "220252",
#                "estabelecimento_municipio_codigo": "355030",
#                "estabelecimento_valor": "4050088",
#                "vacina_nome": "COVID-19 SINOVAC/BUTANTAN - CORONAVAC",
#                "ds_condicao_maternal": null,
#                "paciente_endereco_coPais": "10",
#                "@version": "1",
#                "document_id": "d784dd2d-87e3-4e45-be44-48a6590d9b0f-i0b0",
#                "paciente_nacionalidade_enumNacionalidade": "B",
#                "vacina_categoria_codigo": "2",
#                "vacina_fabricante_referencia": null,
#                "paciente_id": "9715d6ff394f51e1fa50d85b32e8d89541f289ede49133cd1b4120a7dcfecbae",
#                "paciente_idade": 67,
#                "vacina_descricao_dose": "2\u00ba Refor\u00e7o",
#                "paciente_endereco_coIbgeMunicipio": "355030",
#                "vacina_grupoAtendimento_codigo": "000202",
#                "data_importacao_datalake": "2023-02-01T07:14:44.000Z",
#                "paciente_racaCor_codigo": "99",
#                "estabelecimento_uf": "SP",
#                "estabelecimento_razaoSocial": "PREFEITURA DO MUNICIPIO DE SAO PAULO",
#                "vacina_numDose": "7",
#                "@timestamp": "2023-02-01T09:17:24.207Z",
#                "sistema_origem": "VACIVIDA",
#                "paciente_dataNascimento": "1955-04-06",
#                "paciente_endereco_uf": "SP",
#                "vacina_fabricante_nome": "SINOVAC/BUTANTAN",
#                "paciente_endereco_cep": "03582",
#                "id_sistema_origem": "18262",
#                "status": "entered-in-error",
#                "paciente_endereco_nmPais": "BRASIL",
#                "vacina_categoria_nome": "Faixa Et\u00e1ria",
#                "paciente_endereco_nmMunicipio": "SAO PAULO",
#                "estabelecimento_municipio_nome": "SAO PAULO",
#                "vacina_codigo": "86",
#                "paciente_enumSexoBiologico": "F",
#                "dt_deleted": "2023-02-01T00:00:00.000Z",
#                "co_condicao_maternal": null,
#                "vacina_grupoAtendimento_nome": "Pessoas de 65 a 69 anos",
#                "paciente_racaCor_valor": "SEM INFORMACAO",
#                "vacina_dataAplicacao": "2022-11-01T00:00:00.000Z",
#                "data_importacao_rnds": "2022-11-01T14:06:25.000Z"
#             }
#          },
#          {
#             "_index": "desc-imunizacao-v5",
#             "_type": "_doc",
#             "_id": "c0eb9ce1-f0da-4716-98c7-abd463ed91aa-i0b0",
#             "_score": 1.0,
#             "_source": {
#                "estalecimento_noFantasia": "UBS DONA LUIZA",
#                "vacina_lote": "FT5177",
#                "estabelecimento_municipio_codigo": "351880",
#                "estabelecimento_valor": "9130756",
#                "vacina_nome": "COVID-19 PFIZER - COMIRNATY",
#                "ds_condicao_maternal": null,
#                "paciente_endereco_coPais": "10",
#                "@version": "1",
#                "document_id": "c0eb9ce1-f0da-4716-98c7-abd463ed91aa-i0b0",
#                "paciente_nacionalidade_enumNacionalidade": "B",
#                "vacina_categoria_codigo": "2",
#                "vacina_fabricante_referencia": null,
#                "paciente_id": "74d5cf2bb28292a18bdaa875bfeb7a59e8bc6e36031271bc6167f6e356df6176",
#                "paciente_idade": 22,
#                "vacina_descricao_dose": "2\u00ba Refor\u00e7o",
#                "paciente_endereco_coIbgeMunicipio": "351880",
#                "vacina_grupoAtendimento_codigo": "000201",
#                "data_importacao_datalake": "2023-02-01T07:14:44.000Z",
#                "paciente_racaCor_codigo": "04",
#                "estabelecimento_uf": "SP",
#                "estabelecimento_razaoSocial": "MUNICIPIO DE GUARULHOS",
#                "vacina_numDose": "7",
#                "@timestamp": "2023-02-01T09:17:24.208Z",
#                "sistema_origem": "VACIVIDA",
#                "paciente_dataNascimento": "2000-01-31",
#                "paciente_endereco_uf": "SP",
#                "vacina_fabricante_nome": "PFIZER",
#                "paciente_endereco_cep": "07270",
#                "id_sistema_origem": "18262",
#                "status": "entered-in-error",
#                "paciente_endereco_nmPais": "BRASIL",
#                "vacina_categoria_nome": "Faixa Et\u00e1ria",
#                "paciente_endereco_nmMunicipio": "GUARULHOS",
#                "estabelecimento_municipio_nome": "GUARULHOS",
#                "vacina_codigo": "87",
#                "paciente_enumSexoBiologico": "M",
#                "dt_deleted": "2023-02-01T00:00:00.000Z",
#                "co_condicao_maternal": null,
#                "vacina_grupoAtendimento_nome": "Pessoas de 18 a 64 anos",
#                "paciente_racaCor_valor": "AMARELA",
#                "vacina_dataAplicacao": "2022-11-05T00:00:00.000Z",
#                "data_importacao_rnds": "2022-11-05T18:35:43.000Z"
#             }
#          },
#          {
#             "_index": "desc-imunizacao-v5",
#             "_type": "_doc",
#             "_id": "c2891871-74bd-42fc-8f45-0d245539c303-i0b0",
#             "_score": 1.0,
#             "_source": {
#                "estalecimento_noFantasia": "UBS JARDIM GUARANI",
#                "vacina_lote": "220253",
#                "estabelecimento_municipio_codigo": "355030",
#                "estabelecimento_valor": "2787415",
#                "vacina_nome": "COVID-19 SINOVAC/BUTANTAN - CORONAVAC",
#                "ds_condicao_maternal": null,
#                "paciente_endereco_coPais": "10",
#                "@version": "1",
#                "document_id": "c2891871-74bd-42fc-8f45-0d245539c303-i0b0",
#                "paciente_nacionalidade_enumNacionalidade": "B",
#                "vacina_categoria_codigo": "2",
#                "vacina_fabricante_referencia": null,
#                "paciente_id": "bedb3b96a008fcb44ff1ea438db55c4e1ee2c725048c7701d3508aa510e1a06b",
#                "paciente_idade": 19,
#                "vacina_descricao_dose": "Refor\u00e7o",
#                "paciente_endereco_coIbgeMunicipio": "351880",
#                "vacina_grupoAtendimento_codigo": "000201",
#                "data_importacao_datalake": "2023-02-01T07:14:44.000Z",
#                "paciente_racaCor_codigo": "99",
#                "estabelecimento_uf": "SP",
#                "estabelecimento_razaoSocial": "PREFEITURA DO MUNICIPIO DE SAO PAULO",
#                "vacina_numDose": "38",
#                "@timestamp": "2023-02-01T09:17:24.209Z",
#                "sistema_origem": "VACIVIDA",
#                "paciente_dataNascimento": "2003-09-21",
#                "paciente_endereco_uf": "SP",
#                "vacina_fabricante_nome": "SINOVAC/BUTANTAN",
#                "paciente_endereco_cep": "07075",
#                "id_sistema_origem": "18262",
#                "status": "entered-in-error",
#                "paciente_endereco_nmPais": "BRASIL",
#                "vacina_categoria_nome": "Faixa Et\u00e1ria",
#                "paciente_endereco_nmMunicipio": "GUARULHOS",
#                "estabelecimento_municipio_nome": "SAO PAULO",
#                "vacina_codigo": "86",
#                "paciente_enumSexoBiologico": "M",
#                "dt_deleted": "2023-02-01T00:00:00.000Z",
#                "co_condicao_maternal": null,
#                "vacina_grupoAtendimento_nome": "Pessoas de 18 a 64 anos",
#                "paciente_racaCor_valor": "SEM INFORMACAO",
#                "vacina_dataAplicacao": "2022-11-29T00:00:00.000Z",
#                "data_importacao_rnds": "2022-11-29T14:19:45.000Z"
#             }
#          },
#          {
#             "_index": "desc-imunizacao-v5",
#             "_type": "_doc",
#             "_id": "f156849d-2a55-4aa0-9f34-44cec1e6ac29-i0b0",
#             "_score": 1.0,
#             "_source": {
#                "estalecimento_noFantasia": "CS II JOSE F ROSAS",
#                "vacina_lote": "220255",
#                "estabelecimento_municipio_codigo": "353860",
#                "estabelecimento_valor": "2040514",
#                "vacina_nome": "COVID-19 SINOVAC/BUTANTAN - CORONAVAC",
#                "ds_condicao_maternal": null,
#                "paciente_endereco_coPais": "10",
#                "@version": "1",
#                "document_id": "f156849d-2a55-4aa0-9f34-44cec1e6ac29-i0b0",
#                "paciente_nacionalidade_enumNacionalidade": "B",
#                "vacina_categoria_codigo": "2",
#                "vacina_fabricante_referencia": null,
#                "paciente_id": "17ba11c5266c83364ea98765df07344c0f01c401ffba52567e62069cefba7d0e",
#                "paciente_idade": 24,
#                "vacina_descricao_dose": "Refor\u00e7o",
#                "paciente_endereco_coIbgeMunicipio": "353860",
#                "vacina_grupoAtendimento_codigo": "000201",
#                "data_importacao_datalake": "2023-02-01T07:14:44.000Z",
#                "paciente_racaCor_codigo": "99",
#                "estabelecimento_uf": "SP",
#                "estabelecimento_razaoSocial": "PREFEITURA MUNICIPAL DE PIRACAIA",
#                "vacina_numDose": "38",
#                "@timestamp": "2023-02-01T09:17:24.212Z",
#                "sistema_origem": "VACIVIDA",
#                "paciente_dataNascimento": "1998-05-17",
#                "paciente_endereco_uf": "SP",
#                "vacina_fabricante_nome": "SINOVAC/BUTANTAN",
#                "paciente_endereco_cep": "12970",
#                "id_sistema_origem": "18262",
#                "status": "entered-in-error",
#                "paciente_endereco_nmPais": "BRASIL",
#                "vacina_categoria_nome": "Faixa Et\u00e1ria",
#                "paciente_endereco_nmMunicipio": "PIRACAIA",
#                "estabelecimento_municipio_nome": "PIRACAIA",
#                "vacina_codigo": "86",
#                "paciente_enumSexoBiologico": "F",
#                "dt_deleted": "2023-02-01T00:00:00.000Z",
#                "co_condicao_maternal": null,
#                "vacina_grupoAtendimento_nome": "Pessoas de 18 a 64 anos",
#                "paciente_racaCor_valor": "SEM INFORMACAO",
#                "vacina_dataAplicacao": "2022-12-07T00:00:00.000Z",
#                "data_importacao_rnds": "2022-12-07T14:37:04.000Z"
#             }
#          }
#       ]
#    }
# }

# %%
print(payload)
# Out:
# {'size': 5, 'scroll_id': '...', 'scroll': '1m'}

# %% [markdown]
# Let's define a preprocessing function for each page so I won't run out of space in my hard drive.

# %%
def preprocess_index(df):
    return df.set_index(['document_id', 'paciente_id'])

def preprocess_drop_invalid_rows(df):
    return df[df['status']=='final']

def preprocess_drop_cols(df):
    return df[
        [
            'estabelecimento_uf',
            'vacina_dataAplicacao',
            'vacina_nome',
        ]
    ]

def preprocess_dtype(df):
    df['vacina_dataAplicacao'] = pd.to_datetime(df['vacina_dataAplicacao'])
    df['estabelecimento_uf'] = df['estabelecimento_uf'].astype('category')
    df['vacina_nome'] = df['vacina_nome'].astype('category')

    return df

def preprocess(df):
    df_raw = df.copy()

    df = (df_raw
        .pipe(preprocess_index)
        .pipe(preprocess_drop_invalid_rows)
        .pipe(preprocess_drop_cols)
        .pipe(preprocess_dtype)
    )

    return df

# %%
HITS_PER_PAGE = 10000
full_dfs = None

# first page POST params
payload = {
    'size': HITS_PER_PAGE
}

# extract first page
html = requests.post(COVIDJAB_API_URL_FIRST, 
    auth = api_auth,
    json = payload,
)
response_json = html.json()

hits = response_json['hits']['hits']
total_hits = response_json['hits']['total']['value']
total_pages = total_hits // HITS_PER_PAGE
page_count = 0

while hits:
    # get scroll id for making next page request
    scroll_id = response_json['_scroll_id']

    # getting the data into a dataframe
    dataframe_dict = [ hit['_source'] for hit in hits]
    single_df = pd.DataFrame(dataframe_dict)

    # accumulate into a single dataframe
    if full_dfs is None: # first page of results
        full_dfs = single_df.copy()
    else: 
        full_dfs = pd.concat([full_dfs, single_df])

    # extract subsequent pages
    payload = {
        'scroll_id': scroll_id,
        'scroll': '1m'
    }
    
    html = requests.post(COVIDJAB_API_URL, 
        auth = api_auth,
        json = payload,
    )
    response_json = html.json()
    hits = response_json['hits']['hits']
    
    # progress display
    page_count += 1
    if not page_count % 10:
        print(f'Page count: {page_count} of {total_pages} ({page_count/total_pages:.1%} done)')
# Out:
# Page count: 10 of 53959 (0.0% done)
# Page count: 20 of 53959 (0.0% done)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[114], line 41
#      35 # extract subsequent pages
#      36 payload = {
#      37     'scroll_id': scroll_id,
#      38     'scroll': '1m'
#      39 }
# ---> 41 html = requests.post(COVIDJAB_API_URL,
#      42     auth = api_auth,
#      43     json = payload,
#      44 )
#      45 response_json = html.json()
#      46 hits = response_json['hits']['hits']
#
# File c:\ProgramData\Anaconda3\envs\covidjab_natality\lib\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File c:\ProgramData\Anaconda3\envs\covidjab_natality\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\ProgramData\Anaconda3\envs\covidjab_natality\lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File c:\ProgramData\Anaconda3\envs\covidjab_natality\lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File c:\ProgramData\Anaconda3\envs\covidjab_natality\lib\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File c:\ProgramData\Anaconda3\envs\covidjab_natality\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File c:\ProgramData\Anaconda3\envs\covidjab_natality\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File c:\ProgramData\Anaconda3\envs\covidjab_natality\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File c:\ProgramData\Anaconda3\envs\covidjab_natality\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File c:\ProgramData\Anaconda3\envs\covidjab_natality\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File c:\ProgramData\Anaconda3\envs\covidjab_natality\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File c:\ProgramData\Anaconda3\envs\covidjab_natality\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File c:\ProgramData\Anaconda3\envs\covidjab_natality\lib\ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File c:\ProgramData\Anaconda3\envs\covidjab_natality\lib\ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
pd.json_normalize(json_data, ['hits', 'hits'])
# Out:
#                _index _type                                        _id  \
# 0  desc-imunizacao-v5  _doc  171a0693-332e-4690-8a51-ae7f0427ddd4-i0b0
# 1  desc-imunizacao-v5  _doc  d784dd2d-87e3-4e45-be44-48a6590d9b0f-i0b0
# 2  desc-imunizacao-v5  _doc  c0eb9ce1-f0da-4716-98c7-abd463ed91aa-i0b0
# 3  desc-imunizacao-v5  _doc  c2891871-74bd-42fc-8f45-0d245539c303-i0b0
# 4  desc-imunizacao-v5  _doc  f156849d-2a55-4aa0-9f34-44cec1e6ac29-i0b0
#
#    _score    _source.estalecimento_noFantasia _source.vacina_lote  \
# 0     1.0  UBS EURIPES DE FATIMA GALDINO PELE             210556A
# 1     1.0       AMA UBS INTEGRADA JD BRASILIA              220252
# 2     1.0                      UBS DONA LUIZA              FT5177
# 3     1.0                  UBS JARDIM GUARANI              220253
# 4     1.0                  CS II JOSE F ROSAS              220255
#
#   _source.estabelecimento_municipio_codigo _source.estabelecimento_valor  \
# 0                                   352310                       2773236
# 1                                   355030                       4050088
# 2                                   351880                       9130756
# 3                                   355030                       2787415
# 4                                   353860                       2040514
#
#                      _source.vacina_nome _source.ds_condicao_maternal  ...  \
# 0  COVID-19 SINOVAC/BUTANTAN - CORONAVAC                         None  ...
# 1  COVID-19 SINOVAC/BUTANTAN - CORONAVAC                         None  ...
# 2            COVID-19 PFIZER - COMIRNATY                         None  ...
# 3  COVID-19 SINOVAC/BUTANTAN - CORONAVAC                         None  ...
# 4  COVID-19 SINOVAC/BUTANTAN - CORONAVAC                         None  ...
#
#   _source.paciente_endereco_nmMunicipio  \
# 0                             GUARULHOS
# 1                             SAO PAULO
# 2                             GUARULHOS
# 3                             GUARULHOS
# 4                              PIRACAIA
#
#   _source.estabelecimento_municipio_nome _source.vacina_codigo  \
# 0                        ITAQUAQUECETUBA                    86
# 1                              SAO PAULO                    86
# 2                              GUARULHOS                    87
# 3                              SAO PAULO                    86
# 4                               PIRACAIA                    86
#
#   _source.paciente_enumSexoBiologico        _source.dt_deleted  \
# 0                                  F  2023-02-01T00:00:00.000Z
# 1                                  F  2023-02-01T00:00:00.000Z
# 2                                  M  2023-02-01T00:00:00.000Z
# 3                                  M  2023-02-01T00:00:00.000Z
# 4                                  F  2023-02-01T00:00:00.000Z
#
#   _source.co_condicao_maternal _source.vacina_grupoAtendimento_nome  \
# 0                         None              Pessoas de 18 a 64 anos
# 1                         None              Pessoas de 65 a 69 anos
# 2                         None              Pessoas de 18 a 64 anos
# 3                         None              Pessoas de 18 a 64 anos
# 4                         None              Pessoas de 18 a 64 anos
#
#    _source.paciente_racaCor_valor _source.vacina_dataAplicacao  \
# 0                         AMARELA     2022-10-03T00:00:00.000Z
# 1                  SEM INFORMACAO     2022-11-01T00:00:00.000Z
# 2                         AMARELA     2022-11-05T00:00:00.000Z
# 3                  SEM INFORMACAO     2022-11-29T00:00:00.000Z
# 4                  SEM INFORMACAO     2022-12-07T00:00:00.000Z
#
#   _source.data_importacao_rnds
# 0     2022-10-03T19:06:24.000Z
# 1     2022-11-01T14:06:25.000Z
# 2     2022-11-05T18:35:43.000Z
# 3     2022-11-29T14:19:45.000Z
# 4     2022-12-07T14:37:04.000Z
#
# [5 rows x 46 columns]

# %%
dataframe_dict = [ rec['_source'] for rec in json_data['hits']['hits']]
pd.DataFrame(dataframe_dict)
# Out:
#              estalecimento_noFantasia vacina_lote  \
# 0  UBS EURIPES DE FATIMA GALDINO PELE     210556A
# 1       AMA UBS INTEGRADA JD BRASILIA      220252
# 2                      UBS DONA LUIZA      FT5177
# 3                  UBS JARDIM GUARANI      220253
# 4                  CS II JOSE F ROSAS      220255
#
#   estabelecimento_municipio_codigo estabelecimento_valor  \
# 0                           352310               2773236
# 1                           355030               4050088
# 2                           351880               9130756
# 3                           355030               2787415
# 4                           353860               2040514
#
#                              vacina_nome ds_condicao_maternal  \
# 0  COVID-19 SINOVAC/BUTANTAN - CORONAVAC                 None
# 1  COVID-19 SINOVAC/BUTANTAN - CORONAVAC                 None
# 2            COVID-19 PFIZER - COMIRNATY                 None
# 3  COVID-19 SINOVAC/BUTANTAN - CORONAVAC                 None
# 4  COVID-19 SINOVAC/BUTANTAN - CORONAVAC                 None
#
#   paciente_endereco_coPais @version  \
# 0                       10        1
# 1                       10        1
# 2                       10        1
# 3                       10        1
# 4                       10        1
#
#                                  document_id  \
# 0  171a0693-332e-4690-8a51-ae7f0427ddd4-i0b0
# 1  d784dd2d-87e3-4e45-be44-48a6590d9b0f-i0b0
# 2  c0eb9ce1-f0da-4716-98c7-abd463ed91aa-i0b0
# 3  c2891871-74bd-42fc-8f45-0d245539c303-i0b0
# 4  f156849d-2a55-4aa0-9f34-44cec1e6ac29-i0b0
#
#   paciente_nacionalidade_enumNacionalidade  ... paciente_endereco_nmMunicipio  \
# 0                                        B  ...                     GUARULHOS
# 1                                        B  ...                     SAO PAULO
# 2                                        B  ...                     GUARULHOS
# 3                                        B  ...                     GUARULHOS
# 4                                        B  ...                      PIRACAIA
#
#   estabelecimento_municipio_nome vacina_codigo  paciente_enumSexoBiologico  \
# 0                ITAQUAQUECETUBA            86                           F
# 1                      SAO PAULO            86                           F
# 2                      GUARULHOS            87                           M
# 3                      SAO PAULO            86                           M
# 4                       PIRACAIA            86                           F
#
#                  dt_deleted co_condicao_maternal vacina_grupoAtendimento_nome  \
# 0  2023-02-01T00:00:00.000Z                 None      Pessoas de 18 a 64 anos
# 1  2023-02-01T00:00:00.000Z                 None      Pessoas de 65 a 69 anos
# 2  2023-02-01T00:00:00.000Z                 None      Pessoas de 18 a 64 anos
# 3  2023-02-01T00:00:00.000Z                 None      Pessoas de 18 a 64 anos
# 4  2023-02-01T00:00:00.000Z                 None      Pessoas de 18 a 64 anos
#
#   paciente_racaCor_valor      vacina_dataAplicacao      data_importacao_rnds
# 0                AMARELA  2022-10-03T00:00:00.000Z  2022-10-03T19:06:24.000Z
# 1         SEM INFORMACAO  2022-11-01T00:00:00.000Z  2022-11-01T14:06:25.000Z
# 2                AMARELA  2022-11-05T00:00:00.000Z  2022-11-05T18:35:43.000Z
# 3         SEM INFORMACAO  2022-11-29T00:00:00.000Z  2022-11-29T14:19:45.000Z
# 4         SEM INFORMACAO  2022-12-07T00:00:00.000Z  2022-12-07T14:37:04.000Z
#
# [5 rows x 42 columns]

# %%
full_dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 220000 entries, 0 to 9999
# Data columns (total 42 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   estalecimento_noFantasia                  220000 non-null  object
#  1   vacina_lote                               217882 non-null  object
#  2   estabelecimento_municipio_codigo          220000 non-null  object
#  3   estabelecimento_valor                     220000 non-null  object
#  4   vacina_nome                               220000 non-null  object
#  5   ds_condicao_maternal                      71900 non-null   object
#  6   paciente_endereco_coPais                  219977 non-null  object
#  7   @version                                  220000 non-null  object
#  8   document_id                               220000 non-null  object
#  9   paciente_nacionalidade_enumNacionalidade  219996 non-null  object
#  10  vacina_categoria_codigo                   189638 non-null  object
#  11  vacina_fabricante_referencia              87473 non-null   object
#  12  paciente_id                               219997 non-null  object
#  13  paciente_idade                            219997 non-null  float64
#  14  vacina_descricao_dose                     219942 non-null  object
#  15  paciente_endereco_coIbgeMunicipio         219977 non-null  object
#  16  vacina_grupoAtendimento_codigo            216831 non-null  object
#  17  data_importacao_datalake                  220000 non-null  object
#  18  paciente_racaCor_codigo                   219997 non-null  object
#  19  estabelecimento_uf                        220000 non-null  object
#  20  estabelecimento_razaoSocial               220000 non-null  object
#  21  vacina_numDose                            220000 non-null  object
#  22  @timestamp                                220000 non-null  object
#  23  sistema_origem                            220000 non-null  object
#  24  paciente_dataNascimento                   219997 non-null  object
#  25  paciente_endereco_uf                      219977 non-null  object
#  26  vacina_fabricante_nome                    220000 non-null  object
#  27  paciente_endereco_cep                     219849 non-null  object
#  28  id_sistema_origem                         220000 non-null  object
#  29  status                                    220000 non-null  object
#  30  paciente_endereco_nmPais                  219977 non-null  object
#  31  vacina_categoria_nome                     189638 non-null  object
#  32  paciente_endereco_nmMunicipio             219977 non-null  object
#  33  estabelecimento_municipio_nome            220000 non-null  object
#  34  vacina_codigo                             220000 non-null  object
#  35  paciente_enumSexoBiologico                219997 non-null  object
#  36  dt_deleted                                13532 non-null   object
#  37  co_condicao_maternal                      71955 non-null   float64
#  38  vacina_grupoAtendimento_nome              209928 non-null  object
#  39  paciente_racaCor_valor                    219997 non-null  object
#  40  vacina_dataAplicacao                      220000 non-null  object
#  41  data_importacao_rnds                      220000 non-null  object
# dtypes: float64(2), object(40)
# memory usage: 72.2+ MB

# %%
full_dfs['status'].value_counts(normalize = True)
# Out:
# final               0.938491
# entered-in-error    0.061509
# Name: status, dtype: float64

# %%
pre_df = preprocess(full_dfs[full_dfs['paciente_idade']>=18])

# %%
pre_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 164775 entries, ('39e44af5-3a9b-4370-bee6-c28b86534ce9-i0b0', 'e48bffae6603281e2cd42acb403cd5276373502e862abdbfa9031899d2904c02') to ('801f57e6-aebc-49f0-add6-cbde04fe9791-i0b0', '976d4725bcda278e055cf2a01aa0d928a9447971f7647198f4902259f44d36bd')
# Data columns (total 3 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   estabelecimento_uf    164775 non-null  category
#  1   vacina_dataAplicacao  164775 non-null  datetime64[ns, UTC]
#  2   vacina_nome           164775 non-null  category
# dtypes: category(2), datetime64[ns, UTC](1)
# memory usage: 13.6+ MB

# %%
pre_df['vacina_nome'].value_counts()
# Out:
# COVID-19 PFIZER - COMIRNATY                  84874
# COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD    32982
# COVID-19 JANSSEN - Ad26.COV2.S               29191
# COVID-19 SINOVAC/BUTANTAN - CORONAVAC        16391
# COVID-19 ASTRAZENECA - ChAdOx1-S              1213
# COVID-19 PFIZER - COMIRNATY PEDIÁTRICA          58
# COVID-19 SINOVAC - CORONAVAC                    58
# COVID-19 PEDIÁTRICA - PFIZER COMIRNATY           8
# Name: vacina_nome, dtype: int64

# %%
full_dfs[full_dfs['paciente_idade']>=18]['vacina_nome'].value_counts()
# Out:
# COVID-19 PFIZER - COMIRNATY                  549
# COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD    174
# COVID-19 SINOVAC/BUTANTAN - CORONAVAC         65
# COVID-19 JANSSEN - Ad26.COV2.S                47
# COVID-19 ASTRAZENECA - ChAdOx1-S               6
# COVID-19 PFIZER - COMIRNATY PEDIÁTRICA         2
# COVID-19 SINOVAC - CORONAVAC                   1
# Name: vacina_nome, dtype: int64

# %%
full_dfs[(full_dfs['paciente_idade']>=18)&full_dfs['vacina_nome'].str.lower().str.contains('pedi')][['paciente_idade', 'vacina_nome']]
# Out:
#    paciente_idade                             vacina_nome
# 2              44  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA
# 2              22  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA

# %%
def mechanisms(name):
    name = name.lower()
    if 'comirnaty' in name:
        return 'mrna'
    elif 'coronavac' in name:
        return 'inactivated'
    elif 'novavax' in name:
        return 'subunit'
    elif 'covishield' in name or 'chad' in name or 'ad26' in name or 'sputnik' in name:
        return 'viral_vector'
    else:
        return 'unknown'
    
full_dfs['mechanism'] = full_dfs['vacina_nome'].apply(mechanisms)

# %%
full_dfs['mechanism'].value_counts(normalize = True)
# Out:
# mrna            0.527032
# viral_vector    0.311636
# inactivated     0.161332
# Name: mechanism, dtype: float64

# %%
jabs_by_uf_month_type = pre_df.groupby([pd.Grouper(key = 'vacina_dataAplicacao', freq = 'M'), 'estabelecimento_uf', 'vacina_nome']).size()

# %%
jabs_by_uf_month_type[jabs_by_uf_month_type>0]
# Out:
# vacina_dataAplicacao       estabelecimento_uf  vacina_nome
# 2001-06-30 00:00:00+00:00  PR                  COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD      1
# 2007-07-31 00:00:00+00:00  SC                  COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD      1
# 2020-01-31 00:00:00+00:00  RJ                  COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD      1
# 2020-08-31 00:00:00+00:00  AM                  COVID-19 PFIZER - COMIRNATY                    1
# 2020-09-30 00:00:00+00:00  SP                  COVID-19 PFIZER - COMIRNATY                    2
#                                                                                            ...
# 2023-02-28 00:00:00+00:00  SE                  COVID-19 PFIZER - COMIRNATY                   15
#                            SP                  COVID-19 JANSSEN - Ad26.COV2.S                 2
#                                                COVID-19 PFIZER - COMIRNATY                  389
#                                                COVID-19 SINOVAC/BUTANTAN - CORONAVAC         42
#                            TO                  COVID-19 PFIZER - COMIRNATY                    2
# Length: 1895, dtype: int64
